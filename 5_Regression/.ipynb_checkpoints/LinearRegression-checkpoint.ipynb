# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, r2_score

x_points = np.array([1, 2, 3, 4, 5, 6, 7])
y_points = np.array([1.5, 3.8, 6.7, 9.0, 11.2, 13.6, 16])

x_points = x_points.reshape(-1, 1)


model = LinearRegression()

model.fit(x_points, y_points)

y_predictions = model.predict(x_points)

print(y_predictions)
plt.scatter(x_points, y_points, label='Data Points', color='blue')

plt.plot(x_points, y_predictions, label='Best-Fit Line', color='red')

plt.plot(x_points, y_points, label='Original Line', color='green')

plt.xlabel('X')
plt.ylabel('Y')
plt.title('Linear Regression: Best-Fit Line vs. Original Line')
plt.legend()

plt.grid(True)
plt.show()

#In linear regression, you don't typically directly use the error epsilon (ε) in your code, 
#but you calculate and evaluate the errors to assess the performance of your model.
#Typically, a good model has an R-squared value significantly above 0.5
#A small MSE means that the model's predictions are close to the actual data points.

# Calculate the mean squared error
mse = mean_squared_error(y_points, y_predictions)

# Calculate the R-squared (coefficient of determination)
r2 = r2_score(y_points, y_predictions)

print(f"Mean Squared Error: {mse:.2f}")
print(f"R-squared: {r2:.2f}")
# Out:
# [23.31428571 47.45714286 71.6       ]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 42
#      34 plt.show()
#      36 #In linear regression, you don't typically directly use the error epsilon (ε) in your code,
#      37 #but you calculate and evaluate the errors to assess the performance of your model.
#      38 #Typically, a good model has an R-squared value significantly above 0.5
#      39 #A small MSE means that the model's predictions are close to the actual data points.
#      40
#      41 # Calculate the mean squared error
# ---> 42 mse = mean_squared_error(y_points, y_predictions)
#      44 # Calculate the R-squared (coefficient of determination)
#      45 r2 = r2_score(y_points, y_predictions)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_regression.py:442, in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     382 def mean_squared_error(
#     383     y_true, y_pred, *, sample_weight=None, multioutput="uniform_average", squared=True
#     384 ):
#     385     """Mean squared error regression loss.
#     386
#     387     Read more in the :ref:`User Guide <mean_squared_error>`.
#    (...)
#     440     0.825...
#     441     """
# --> 442     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     443         y_true, y_pred, multioutput
#     444     )
#     445     check_consistent_length(y_true, y_pred, sample_weight)
#     446     output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_regression.py:100, in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      66 def _check_reg_targets(y_true, y_pred, multioutput, dtype="numeric"):
#      67     """Check that y_true and y_pred belong to the same regression task.
#      68
#      69     Parameters
#    (...)
#      98         correct keyword.
#      99     """
# --> 100     check_consistent_length(y_true, y_pred)
#     101     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#     102     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:397, in check_consistent_length(*arrays)
#     395 uniques = np.unique(lengths)
#     396 if len(uniques) > 1:
# --> 397     raise ValueError(
#     398         "Found input variables with inconsistent numbers of samples: %r"
#     399         % [int(l) for l in lengths]
#     400     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [7, 3]
